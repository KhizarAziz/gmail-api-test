# %% [markdown]
# # Search Gmail Messages

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from my_gmail_api import MyGmailAPI

# %%
api = MyGmailAPI() 
api.auth_user()# authentication and connection
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=664479540065-an4mj8g2rjrhks7j0smae366cfbjis0m.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60882%2F&scope=https%3A%2F%2Fmail.google.com%2F&state=leMKjot4F1yPIkDWCvKEowuiPLkZOS&access_type=offline

# %%
USER_ID = 'me'
search_string = 'united states'
messages_list = api.search_messages(USER_ID,search_string)
# Out:
# Found  32 results.

# %%
for ID in messages_list:
    message = api.get_message(user_id=USER_ID, message_id=ID)
    print(f'To: {message.to}\nFrom: {message.msg_from}\nDate: {message.date}\nSubject:{message.subject}\nBody:{message.body}')
# Out:
# To: Khizer Aziz <khizer.awan@gmail.com>
# From: Twitter <info@twitter.com>
# Date: Sun, 03 Apr 2022 19:41:35 +0000
# Subject:People in Rawalpindi shared "For the first time in history,
#  governme...
# Body:What's happening
#
#
#
# Times of Islamabad
#
# For the first time in history, government is happy and opposition is sad ov=
# er dissolution of Assemblies
#
# ISLAMABAD:Pakistan Tehreek-e-Insaf (PTI) leader Chaudhry Fawad Hussain said=
#  on Sunday that under Article 69, the Supr...
#
# Read more at Twitter <https://twitter.com/i/redirect?url=3Dhttps%3A%2F%2Ftw=
# itter.com%2Fi%2Ftopics%2Fnews%2Fe-256503861%3Fcn%3DZmxleGlibGVfcmVjcw%253D%=
# 253D%26refsrc%3Demail&amp;t=3D1+1649014895628&amp;cn=3DZmxleGlibGVfcmVjcw%3=
# D%3D&amp;sig=3Db2054b386891f4b4adfe9491db7960ba38d6acb0&amp;iid=3Dcf9d6a6cf=
# 44c4ca3a7dd7aa53c761e83&amp;uid=3D3180910711&amp;nid=3D244+272830480>
#
# ----------
#
#
#
# yahoo.com
#
# Pakistan Default Risk Soars, Currency Sinks on Political Turmoil
#
# ...

# %% [markdown]
# # Send Gmail Messages

# %%
USER_ID = 'me' 
to = 'khizer.awan1992@gmail.com'
subject = '2nd email'
body = ' hello ths email is to inform you that i have created the send email method inside my_gmail_api script...!'
api.send_email(USER_ID,to,subject,body)
# Out:
# message sent!
